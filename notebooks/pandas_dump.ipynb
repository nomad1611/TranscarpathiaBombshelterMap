# %%
import pandas as pd
data = [100, 12, 5, 707, 1, 32, 222, -10]
series = pd.Series(data, index=["a","b", "d", "e", "f", "g", "h", "j"])
output = series[series < 50]
print(output)
# Out:
# b    12
# d     5
# f     1
# g    32
# j   -10
# dtype: int64

# %%
calories = {"Day 1" : 1750, "Day 2": 2200, "Day 3": 1000, "Day 5": 1660, "Day 5": 1740 }
series = pd.Series(calories)

print(series[series <= 1600])
# Out:
# Day 3    1000
# dtype: int64

# %%
from ..notebooks import APIbombshelterZak as bs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 from ..notebooks import APIbombshelterZak as bs
#
# ImportError: attempted relative import with no known parent package
